# %% [markdown]
# # Pattern mining

# %%
# https://data-mining.philippe-fournier-viger.com/introduction-to-sequential-rule-mining/

# %%
# %pip install awswrangler
# %pip install apyori
# %pip install pyfpgrowth

# %%
import os 
import json
import boto3 
import random
#import pyfpgrowth
import numpy as np
import pandas as pd
import awswrangler as wr
from apyori import apriori

from sagemaker import get_execution_role
role = get_execution_role()

# %%
selected_region='cosr-nco'
bucket = 'ons-dl-dev-landing'
prefix = 'ons/mpo_ds_nlp/data/postprocessed_output/spacy/sentences/entities-'+selected_region+'.parquet'
input_uri = 's3://{}/{}'.format(bucket, prefix)
df = pd.read_parquet(input_uri)
df
# Out:
#                                                    text  \
# 0     desenergização da lt 230 kv tucuruí / altamira...
# 1     procedimentosobjetivo / item de controle1---co...
# 2     2cosr-ncocosr-ncoequatorialdesligar o religame...
# 3     3cosr-ncocosr-ncoeletronorteabrir o terminal d...
# 4     - reator da lt disponível:se tucuruí ≤ 232 kv-...
# ...                                                 ...
# 3312  estando a transformação 500/230 kv da se sinop...
# 3313  1cosr-ncocosr-ncocos-state gridenergizar a lt ...
# 3314  - transformação 500/230 kv da se sinop desligada.
# 3315  - tensão na se sinop superior a 508 kv  e  ≤ 5...
# 3316        - ce da se paranatinga na faixa capacitiva.
#
#                                                  entity  \
# 0        [desenergização, lt 230 kv tucuruí / altamira]
# 1     [verificar, indisponibilidade, lt 230 kv tucur...
# 2     [religamento automático tripolar da lt 230 kv ...
# 3           [lt 230 kv tucuruí / altamira, se altamira]
# 4     [reator da lt, se tucuruí, ≤, 232 kv-, reator ...
# ...                                                 ...
# 3312                                      [em operação]
# 3313  [lt 500 kv cláudia / sinop, pelo terminal da, ...
# 3314                                        [desligada]
# 3315  [tensão, se sinop, superior a, 508 kv, e  ≤, s...
# 3316                             [ce da se paranatinga]
#
#                                                    type
# 0                        [ACAO_A_EXECUTAR, EQUIPAMENTO]
# 1      [ACAO_A_EXECUTAR, ESTADO_OPERATIVO, EQUIPAMENTO]
# 2                                         [EQUIPAMENTO]
# 3                             [EQUIPAMENTO, SUBESTACAO]
# 4     [EQUIPAMENTO, SUBESTACAO, OPERADOR_MATEMATICO,...
# ...                                                 ...
# 3312                                 [ESTADO_OPERATIVO]
# 3313         [EQUIPAMENTO, ACAO_A_EXECUTAR, SUBESTACAO]
# 3314                                  [ACAO_A_EXECUTAR]
# 3315  [VALOR_COM_UNID.MEDIDA, SUBESTACAO, OPERADOR_M...
# 3316                                      [EQUIPAMENTO]
#
# [3317 rows x 3 columns]

# %%
df = df[df['entity'].map(lambda d: len(d)) > 0]
df
# Out:
#                                                    text  \
# 0     desenergização da lt 230 kv tucuruí / altamira...
# 1     procedimentosobjetivo / item de controle1---co...
# 2     2cosr-ncocosr-ncoequatorialdesligar o religame...
# 3     3cosr-ncocosr-ncoeletronorteabrir o terminal d...
# 4     - reator da lt disponível:se tucuruí ≤ 232 kv-...
# ...                                                 ...
# 3312  estando a transformação 500/230 kv da se sinop...
# 3313  1cosr-ncocosr-ncocos-state gridenergizar a lt ...
# 3314  - transformação 500/230 kv da se sinop desligada.
# 3315  - tensão na se sinop superior a 508 kv  e  ≤ 5...
# 3316        - ce da se paranatinga na faixa capacitiva.
#
#                                                  entity  \
# 0        [desenergização, lt 230 kv tucuruí / altamira]
# 1     [verificar, indisponibilidade, lt 230 kv tucur...
# 2     [religamento automático tripolar da lt 230 kv ...
# 3           [lt 230 kv tucuruí / altamira, se altamira]
# 4     [reator da lt, se tucuruí, ≤, 232 kv-, reator ...
# ...                                                 ...
# 3312                                      [em operação]
# 3313  [lt 500 kv cláudia / sinop, pelo terminal da, ...
# 3314                                        [desligada]
# 3315  [tensão, se sinop, superior a, 508 kv, e  ≤, s...
# 3316                             [ce da se paranatinga]
#
#                                                    type
# 0                        [ACAO_A_EXECUTAR, EQUIPAMENTO]
# 1      [ACAO_A_EXECUTAR, ESTADO_OPERATIVO, EQUIPAMENTO]
# 2                                         [EQUIPAMENTO]
# 3                             [EQUIPAMENTO, SUBESTACAO]
# 4     [EQUIPAMENTO, SUBESTACAO, OPERADOR_MATEMATICO,...
# ...                                                 ...
# 3312                                 [ESTADO_OPERATIVO]
# 3313         [EQUIPAMENTO, ACAO_A_EXECUTAR, SUBESTACAO]
# 3314                                  [ACAO_A_EXECUTAR]
# 3315  [VALOR_COM_UNID.MEDIDA, SUBESTACAO, OPERADOR_M...
# 3316                                      [EQUIPAMENTO]
#
# [3317 rows x 3 columns]

# %%
entity_sequence = df['type'].to_list()
# entity_sequence[0:2]

# %% [markdown]
# ## Frequent Pattern

# %%
# #Finding the frequent patterns with min support threshold=0.5
# FrequentPatterns=pyfpgrowth.find_frequent_patterns(entity_sequence,support_threshold=0.5)
# print(FrequentPatterns)
 
# # Generating rules with min confidence threshold=0.5
# Rules=pyfpgrowth.generate_association_rules(patterns=FrequentPatterns,confidence_threshold=0.5)
# Rules

# %% [markdown]
# ## RHS and LHS

# %%
rules_dict = {
    'rhs':[],
    'lhs':[],
    'support':[],
    'confidence':[],
    'lift':[]
}

rules = apriori(entity_sequence, min_support = 0.05, min_confidence = 0.58, min_lift=1.15, min_length = 2, max_length=3)
rules = list(rules)
rules

# Extracting rules from the object
for i in range(len(rules)):
    rules_dict['rhs'].append(list(rules[i][2][0][0]))
    rules_dict['lhs'].append(list(rules[i][2][0][1]))
    rules_dict['support'].append(rules[i][1])
    rules_dict['confidence'].append(rules[i][2][0][2])
    rules_dict['lift'].append(rules[i][2][0][3])

rules_df = pd.DataFrame(rules_dict)
rules_df.sort_values(by=['lift','confidence'], ascending=False, inplace=True)
rules_df.reset_index(drop=True, inplace=True)
rules_df.head(60)
# Out:
#                                         rhs  \
# 0                     [OPERADOR_MATEMATICO]
# 1                     [OPERADOR_MATEMATICO]
# 2        [OPERADOR_MATEMATICO, EQUIPAMENTO]
# 3             [ACAO_A_EXECUTAR, SUBESTACAO]
# 4  [VALOR_COM_UNID.MEDIDA, ACAO_A_EXECUTAR]
# 5                     [OPERADOR_MATEMATICO]
# 6                         [ACAO_A_EXECUTAR]
# 7        [OPERADOR_MATEMATICO, EQUIPAMENTO]
#
#                                    lhs   support  confidence      lift
# 0  [VALOR_COM_UNID.MEDIDA, SUBESTACAO]  0.199879    0.729373  2.784039
# 1              [VALOR_COM_UNID.MEDIDA]  0.258366    0.942794  2.394524
# 2              [VALOR_COM_UNID.MEDIDA]  0.069641    0.895349  2.274022
# 3                        [EQUIPAMENTO]  0.182997    0.854930  1.359445
# 4                        [EQUIPAMENTO]  0.056678    0.828194  1.316931
# 5                         [SUBESTACAO]  0.205909    0.751375  1.282053
# 6                        [EQUIPAMENTO]  0.291528    0.793273  1.261403
# 7                         [SUBESTACAO]  0.056075    0.720930  1.230106

# %%
len(rules_df)
# Out:
# 8

# %% [markdown]
# ### Pattern example

# %%
df['entity'].iloc[0]
# Out:
# array(['desenergização', 'lt 230 kv tucuruí / altamira'], dtype=object)

# %% [markdown]
# ## Raw sequence

# %%
rules_dict = {
    'sequence':[],
    'support':[],
    'confidence':[],
    'lift':[]
}

association_rules = apriori(entity_sequence, min_support = 0.05, min_confidence = 0.55, min_lift=1.10, min_length = 2, max_length=4)
association_rules = list(association_rules)

for item in association_rules:
    rules_dict['sequence'].append(list(item[0]))
    rules_dict['support'].append(item[1])
    rules_dict['confidence'].append(item[2][0][2])
    rules_dict['lift'].append(item[2][0][3])

sequence_df = pd.DataFrame(rules_dict)
sequence_df.sort_values(by=['lift','support','confidence'], inplace=True, ascending=False)
sequence_df.reset_index(drop=True, inplace=True)
sequence_df.head(20)
# Out:
#                                             sequence   support  confidence  \
# 0  [VALOR_COM_UNID.MEDIDA, OPERADOR_MATEMATICO, S...  0.199879    0.729373
# 1  [VALOR_COM_UNID.MEDIDA, OPERADOR_MATEMATICO, S...  0.052759    0.678295
# 2       [VALOR_COM_UNID.MEDIDA, OPERADOR_MATEMATICO]  0.258366    0.942794
# 3  [VALOR_COM_UNID.MEDIDA, OPERADOR_MATEMATICO, E...  0.069641    0.895349
# 4         [ACAO_A_EXECUTAR, SUBESTACAO, EQUIPAMENTO]  0.182997    0.854930
# 5  [VALOR_COM_UNID.MEDIDA, ACAO_A_EXECUTAR, EQUIP...  0.056678    0.828194
# 6                  [OPERADOR_MATEMATICO, SUBESTACAO]  0.205909    0.751375
# 7                     [ACAO_A_EXECUTAR, EQUIPAMENTO]  0.291528    0.793273
# 8     [OPERADOR_MATEMATICO, SUBESTACAO, EQUIPAMENTO]  0.056075    0.720930
# 9                [VALOR_COM_UNID.MEDIDA, SUBESTACAO]  0.261984    0.665391
#
#        lift
# 0  2.784039
# 1  2.589071
# 2  2.394524
# 3  2.274022
# 4  1.359445
# 5  1.316931
# 6  1.282053
# 7  1.261403
# 8  1.230106
# 9  1.135340

# %%
sequence_df['sequence'].iloc[0]
# Out:
# ['VALOR_COM_UNID.MEDIDA', 'OPERADOR_MATEMATICO', 'SUBESTACAO']

# %% [markdown]
# ## Examples

# %%
ex_seq = sequence_df['sequence'].iloc[7]
for index, row in df.iterrows():
    if all(item in row['type'] for item in ex_seq):
        print(' text: \n',row['text'])
        print(' entities: \n',row['entity'])
        print(' types: \n',row['type'])
        print('-'*10)
# Out:
#  text:
#  desenergização da lt 230 kv tucuruí / altamira (sentido único passocoordenaçãocontrolecomando, execução.
#  entities:
#  ['desenergização' 'lt 230 kv tucuruí / altamira']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  procedimentosobjetivo / item de controle1---cosr-nco---verificar a necessidade de adequações no sistema, para atendimento às limitações impostas pela indisponibilidade lt 230 kv tucuruí / altamira.
#  entities:
#  ['verificar' 'indisponibilidade' 'lt 230 kv tucuruí / altamira']
#  types:
#  ['ACAO_A_EXECUTAR' 'ESTADO_OPERATIVO' 'EQUIPAMENTO']
# ----------
#  text:
#  - reator da lt disponível:se tucuruí ≤ 232 kv- reator da lt indisponível:se tucuruí ≤ 220 kvdesenergizar a lt 230 kv tucuruí / altamira, pelo terminal da se tucuruí.
#  entities:
#  ['reator da lt' 'se tucuruí' '≤' '232 kv-' 'reator da lt' 'se tucuruí' '≤'
#  '220 kvdesenergizar' 'lt 230 kv tucuruí / altamira' 'pelo terminal da'
#  'se tucuruí']
#  types:
#  ['EQUIPAMENTO' 'SUBESTACAO' 'OPERADOR_MATEMATICO' 'VALOR_COM_UNID.MEDIDA'
#  'EQUIPAMENTO' 'SUBESTACAO' 'OPERADOR_MATEMATICO' 'VALOR_COM_UNID.MEDIDA'
#  'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 230 kv tucuruí / altamira (sentido único passocoordenaçãocontrolecomandoprocedimentoslimite / item de controle1cosr-ncocosr-ncoeletronorteenergizar, a partir da se tucuruí, a lt 230 kv tucuruí / altamira.
#  entities:
#  ['lt 230 kv tucuruí / altamira' 'a partir da' 'se tucuruí'
#  'lt 230 kv tucuruí / altamira']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergização da lt 230 kv altamira / xingu3.
#  entities:
#  ['desenergização' 'lt 230 kv altamira / xingu3']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergização da lt 230 kv altamira / xingu (sentido normal passocoordenaçãocontrolecomando, execução.
#  entities:
#  ['desenergização' 'lt 230 kv altamira / xingu' 'sentido normal']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  procedimentosobjetivo / item de controle1---cosr-nco---verificar a necessidade de adequações no sistema, para atendimento às limitações impostas pela indisponibilidade lt 230 kv altamira / xingu.
#  entities:
#  ['verificar' 'indisponibilidade' 'lt 230 kv altamira / xingu']
#  types:
#  ['ACAO_A_EXECUTAR' 'ESTADO_OPERATIVO' 'EQUIPAMENTO']
# ----------
#  text:
#  se xingu ≤ 241 kvdesenergizar a lt 230 kv altamira / xingu, pelo terminal da se xingu.
#  entities:
#  ['se xingu' '≤' '241 kvdesenergizar' 'lt 230 kv altamira / xingu'
#  'pelo terminal da' 'se xingu']
#  types:
#  ['SUBESTACAO' 'OPERADOR_MATEMATICO' 'VALOR_COM_UNID.MEDIDA' 'EQUIPAMENTO'
#  'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv altamira / xingu (sentido inverso passocoordenaçãocontrolecomando, execução.
#  entities:
#  ['desenergização' 'lt 230 kv altamira / xingu' 'sentido inverso']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  procedimentosobjetivo / item de controle1---cosr-nco---verificar a necessidade de adequações no sistema, para atendimento às limitações impostas pela indisponibilidade lt 230 kv altamira / xingu.
#  entities:
#  ['verificar' 'indisponibilidade' 'lt 230 kv altamira / xingu']
#  types:
#  ['ACAO_A_EXECUTAR' 'ESTADO_OPERATIVO' 'EQUIPAMENTO']
# ----------
#  text:
#  se altamira ≤ 241 kvdesenergizar a lt 230 kv altamira / xingu, pelo terminal da se altamira.
#  entities:
#  ['se altamira' '≤' '241 kvdesenergizar' 'lt 230 kv altamira / xingu'
#  'pelo terminal da' 'se altamira']
#  types:
#  ['SUBESTACAO' 'OPERADOR_MATEMATICO' 'VALOR_COM_UNID.MEDIDA' 'EQUIPAMENTO'
#  'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  procedimentosobjetivo / item de controle1cosr-ncocosr-ncoequatorialenergizar a lt 230 kv altamira / xingu, pelo terminal da se xingu.
#  entities:
#  ['lt 230 kv altamira / xingu' 'pelo terminal da' 'se xingu']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv altamira / transamazônica c1 ou c23.
#  entities:
#  ['desenergização' 'lt 230 kv altamira / transamazônica c1 ou c23']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergização da lt 230 kv altamira / transamazônica c1 ou c2 (sentido normal passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronorte (c1 equatorial (c2 abrir o terminal da lt 230 kv altamira / transamazônica c1 ou c2 na se transamazônica.
#  entities:
#  ['desenergização' 'lt 230 kv altamira / transamazônica c1 ou c2'
#  'lt 230 kv altamira / transamazônica c1 ou c2' 'se transamazônica']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 230 kv altamira / transamazônica c1 ou c2, pelo terminal da se altamira.
#  entities:
#  ['desenergizar' 'lt 230 kv altamira / transamazônica c1 ou c2'
#  'pelo terminal da' 'se altamira']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv altamira / transamazônica c1 ou c2 (sentido inverso passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronorte (c1 equatorial (c2 abrir o terminal da lt 230 kv altamira / transamazônica c1 ou c2 na se altamira.
#  entities:
#  ['desenergização' 'lt 230 kv altamira / transamazônica c1 ou c2'
#  'lt 230 kv altamira / transamazônica c1 ou c2' 'se altamira']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 230 kv altamira / transamazônica c1 ou c2, pelo terminal da se transamazônica.
#  entities:
#  ['desenergizar' 'lt 230 kv altamira / transamazônica c1 ou c2'
#  'pelo terminal da' 'se transamazônica']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 230 kv altamira / transamazônica c1 ou c2 a partir da se altamira (sentido normal passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle-estando o reator de linha da lt 230 kv altamira / transamazônica c1 ou c2 indisponível, essa lt não poderá ser energizada.
#  entities:
#  ['a partir da' 'se altamira'
#  'reator de linha da lt 230 kv altamira / transamazônica c1 ou c2'
#  'não poderá ser energizada']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  1cosr-ncocosr-ncoeletronorte (c1 equatorial (c2 energizar a lt 230 kv altamira / transamazônica c1 ou c2 pelo terminal da se altamira.
#  entities:
#  ['lt 230 kv altamira / transamazônica c1 ou c2' 'pelo terminal da'
#  'se altamira']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv transamazônica / rurópolis (sentido único passocoordenaçãocontrolecomandoprocedimentosobjetivo/ item de controle1cosr-ncocosr-nco adotar os procedimentos para a indisponibilidade da lt 230 kv transamazônica / rurópolis.
#  entities:
#  ['desenergização' 'lt 230 kv transamazônica / rurópolis' 'adotar'
#  'indisponibilidade']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'ESTADO_OPERATIVO']
# ----------
#  text:
#  desenergizar a lt 230 kv transamazônica / rurópolis, pelo terminal da se transamazônica.
#  entities:
#  ['desenergizar' 'lt 230 kv transamazônica / rurópolis' 'pelo terminal da'
#  'se transamazônica']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 230 kv transamazônica / rurópolis (sentido único passocoordenaçãocontrolecomandoprocedimentosobjetivo / item de controle1cosr-ncocosr-ncoeletronorteenergizar a lt 230 kv transamazônica / rurópolis, pelo terminal da se transamazônica.
#  entities:
#  ['lt 230 kv transamazônica / rurópolis' 'pelo terminal da'
#  'se transamazônica']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv tapajós ii / transamazônica (sentido único passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-nco adotar os procedimentos para a indisponibilidade da lt 230 kv tapajós ii/ transamazônica.
#  entities:
#  ['desenergização' 'lt 230 kv tapajós ii / transamazônica' 'adotar'
#  'indisponibilidade']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'ESTADO_OPERATIVO']
# ----------
#  text:
#  desenergizar a lt 230 kv tapajós ii / transamazônica, pelo terminal da se transamazônica.
#  entities:
#  ['desenergizar' 'lt 230 kv tapajós ii / transamazônica' 'pelo terminal da'
#  'se transamazônica']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 230 kv tapajós ii / transamazônica a partir da se transamazônica (sentido único passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle-estando um dos reatores de linha da lt 230 kv tapajós ii / transamazônica indisponível, essa lt não poderá ser energizada.
#  entities:
#  ['lt 230 kv tapajós ii / transamazônica' 'se transamazônica'
#  'lt 230 kv tapajós ii / transamazônica' 'não poderá ser energizada']
#  types:
#  ['EQUIPAMENTO' 'SUBESTACAO' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  desenergização da lt 230 kv altamira / pimentalpassocoordenaçãocontrolecomando /execuçãoprocedimentoslimite / item de controle1---cosr-nco---verificar a necessidade de adequações no sistema, para atendimento às limitações impostas pela indisponibilidade da lt 230 kv altamira / pimental, conforme definido na io-oc.n.2tr.
#  entities:
#  ['desenergização'
#  'lt 230 kv altamira / pimentalpassocoordenaçãocontrolecomando /execuçãoprocedimentoslimite / item'
#  'verificar']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  se pimental superior a 218 kv4cosr-ncocosr-ncoeletronortedesenergizar a lt 230 kv altamira / pimental, pelo terminal da se altamira.
#  entities:
#  ['se pimental' 'superior a' 'lt 230 kv altamira / pimental'
#  'pelo terminal da' 'se altamira']
#  types:
#  ['SUBESTACAO' 'OPERADOR_MATEMATICO' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR'
#  'SUBESTACAO']
# ----------
#  text:
#  energização da lt 230 kv altamira / pimental (sentido único passocoordenaçãocontrolecomando /execuçãoprocedimentoslimite / item de controle-o restabelecimento desta lt é coordenado pelo cosr-nco conforme procedimentos a seguir:1cosr-ncocosr-ncoeletronorteenergizar a lt 230 kv altamira / pimental, pelo terminal da se altamira.
#  entities:
#  ['lt 230 kv altamira / pimental' 'pelo terminal da' 'se altamira']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização do autotransformador 9at01 de 500/230/13,8 kv – 336 mva da se xingupassocoordenaçãocontrolecomando execuçãoprocedimentoitem de controle / objetivo1---cosr–nco---verificar a necessidade de adequações no sistema, para atendimento às limitações impostas pela indisponibilidade do autotransformador 9at01 de 500/230/13,8 kv – 336 mva da se xingu.
#  entities:
#  ['desenergização'
#  'autotransformador 9at01 de 500/230/13,8 kv – 336 mva da se xingupassocoordenaçãocontrolecomando'
#  'verificar' 'se xingu']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  3cosr-ncocosr–ncoequatorial, cos-cotesa (lxte desligar o autotransformador 9at01 de 500/230/13,8 kv – 336 mva da se xingu iniciando a manobra, preferencialmente, pelo disjuntor da lxte.
#  entities:
#  ['autotransformador 9at01 de 500/230/13,8 kv – 336 mva da se xingu'
#  'iniciando a manobra,']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização do autotransformador 9at01 de 500/230/13,8 kv – 336 mva da se xingupassocoordenaçãocontrolecomando / execuçãoprocedimentoitem de controle / objetivo-o restabelecimento do autotransformador 9at01 de 500/230/13,8 kv – 336 mva da se xingu é coordenada pelo cosr-nco, conforme a seguir:a energização pelo terminal de 230 kv não é permitida.
#  entities:
#  ['energização'
#  'autotransformador 9at01 de 500/230/13,8 kv – 336 mva da se xingupassocoordenaçãocontrolecomando'
#  'autotransformador 9at01 de 500/230/13,8 kv – 336 mva da se xingu'
#  'energização']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  fechar, em anel, o terminal de 230 kv do autotransformador 9at01 de 500/230/13,8 kv – 336 mva da se xingu.
#  entities:
#  ['o terminal de' '230 kv'
#  'autotransformador 9at01 de 500/230/13,8 kv – 336 mva da' 'se xingu']
#  types:
#  ['ACAO_A_EXECUTAR' 'VALOR_COM_UNID.MEDIDA' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  desenergização do autotransformador ruat6-01 ou 02 ou 03 de 230/138/13,8 kv – 100 mva da se rurópolispassocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronortedesligar o autotransformador ruat6-01 ou 02 ou 03 - 230/138/13,8 kv – 100 mva da se rurópolis iniciando a manobra pelo terminal de 138 kv.
#  entities:
#  ['desenergização'
#  'autotransformador ruat6-01 ou 02 ou 03 de 230/138/13,8 kv – 100 mva da se rurópolispassocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item'
#  'autotransformador ruat6-01 ou 02 ou 03 - 230/138/13,8 kv – 100 mva da se rurópolis'
#  'iniciando a manobra pelo terminal de' '138 kv']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR'
#  'VALOR_COM_UNID.MEDIDA']
# ----------
#  text:
#  energização do autotransformador ruat6-01 ou 02 ou 03 de 230/138/13,8 kv – 100 mva da se rurópolis pelo terminal de 230 kv (sentido único passocoordenaçãocontrolecomando/execuçãoprocedimentoobjetivo / item de controle-o restabelecimento do autotransformador ruat6-01 ou 02 ou 03 - 230/138/13,8 kv – 100 mva da se rurópolis pelo terminal de 230 kv, quando de desligamento automático, é efetuado com autonomia pela operação do agente conforme condições especificadas na io de instalação.
#  entities:
#  ['energização'
#  'autotransformador ruat6-01 ou 02 ou 03 de 230/138/13,8 kv – 100 mva da se rurópolis'
#  'pelo terminal de' '230 kv' 'restabelecimento'
#  'autotransformador ruat6-01 ou 02 ou 03 - 230/138/13,8 kv – 100 mva da se rurópolis'
#  'pelo terminal de']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'VALOR_COM_UNID.MEDIDA'
#  'ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  para desligamentos programados/urgência/emergência ou quando alguma condição da io de instalação não estiver atendida, o restabelecimento deste autotransformador é coordenado pelo cosr-nco, conforme procedimentos a seguir:1cosr-ncocosr-ncoeletronorteenergizar o autotransformador ruat6-01 ou 02 ou 03 - 230/138/13,8 kv – 100 mva da se rurópolis pelo terminal de 230 kv.
#  entities:
#  ['autotransformador ruat6-01 ou 02 ou 03 - 230/138/13,8 kv – 100 mva da se rurópolis'
#  'pelo terminal de' '230 kv']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'VALOR_COM_UNID.MEDIDA']
# ----------
#  text:
#  desenergização do transformador tmtf6-01 ou 02 de 230/34,5 kv – 30 mva da se transamazônicapassocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronortedesligar o transformador tmtf6-01 ou 02- 230/34,5 kv – 30 mva da se transamazônica iniciando a manobra pelo terminal de 34,5 kv.
#  entities:
#  ['desenergização'
#  'transformador tmtf6-01 ou 02- 230/34,5 kv – 30 mva da se transamazônica'
#  'iniciando a manobra pelo terminal de 34,5 kv']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  -  se transamazônica &lt; 242 kv- ltc na posição 13bfechar o terminal de 34,5 kv do transformador tmtf6-01 ou 02 da se transamazônica.
#  entities:
#  ['o terminal de 34,5 kv' 'transformador tmtf6-01 ou 02'
#  'se transamazônica']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  desenergização do autotransformador tcat7-01 ou 02 de 550/242/13,8 kv – 450 mva da se tucuruípassocoordenaçãocontrolecomando/ execuçãoprocedimentoobjetivo / item de controle1---cosr-nco---verificar a necessidade de adequações no sistema, para atendimento às limitações impostas pela indisponibilidade do autotransformador 550/242/13,8 kv da se tucuruí.
#  entities:
#  ['desenergização'
#  'autotransformador tcat7-01 ou 02 de 550/242/13,8 kv – 450 mva da se tucuruípassocoordenaçãocontrolecomando/ execuçãoprocedimentoobjetivo / item'
#  'verificar' 'autotransformador 550/242/13,8 kv da se tucuruí']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  conforme definido na io-oc.n.2tr2cosr-ncocosr-ncoeletronortedesligar o autotransformador 550/242/13,8 kv da se tucuruí iniciando a manobra pelo terminal de 230 kv.
#  entities:
#  ['autotransformador 550/242/13,8 kv da se tucuruí'
#  'iniciando a manobra pelo terminal de' '230 kv']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'VALOR_COM_UNID.MEDIDA']
# ----------
#  text:
#  energização do autotransformador tcat7-01 ou 02 de 550/242/13,8 kv – 450 mva da se tucuruí passocoordenaçãocontrolecomando / execuçãoprocedimentoitem de controle / objetivo-a energização do autotransformador de 550/242/13,8 kv da se tucuruí pelo terminal de 230 kv não é permitida.
#  entities:
#  ['energização'
#  'autotransformador tcat7-01 ou 02 de 550/242/13,8 kv – 450 mva da se tucuruí passocoordenaçãocontrolecomando / execuçãoprocedimentoitem de controle / objetivo-a energização do autotransformador de 550/242/13,8 kv da se tucuruí']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  - conforme definido na io-oc.n.2tr2cosr-ncocosr-ncoeletronortedesligar o transformador tctf6-01 230/69/13,8 kv - 100 mva iniciando a manobra pelo terminal de 69 kv.
#  entities:
#  ['transformador tctf6-01 230/69/13,8 kv - 100 mva' 'pelo terminal de'
#  '69 kv']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'VALOR_COM_UNID.MEDIDA']
# ----------
#  text:
#  energização do transformador tctf6-01 230/69/13,8 kv - 100 mvapassocoordenaçãocontrolecomando/ execuçãoprocedimentoobjetivo / item de controle-o restabelecimento do transformador tctf6-01 de 230/69/13,8 kv - 100 mva da se tucuruí pelo terminal de 230 kv, quando de desligamento automático, é efetuado com autonomia pela operação do agente conforme condições especificadas na io de instalação.
#  entities:
#  ['energização'
#  'transformador tctf6-01 de 230/69/13,8 kv - 100 mva da se tucuruí']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergização do autotransformador tcat6-03 ou 04 230/138/13,8 kv - 100 mvapassocoordenaçãocontrolecomando/ execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronortedesligar o autotransformador tcat6-03 ou tcat6-04 de 230/138/13,8 kv - 100 mva iniciando a manobra pelo terminal de 138 kv.
#  entities:
#  ['desenergização'
#  'autotransformador tcat6-03 ou 04 230/138/13,8 kv - 100 mvapassocoordenaçãocontrolecomando/ execuçãoprocedimentoobjetivo / item'
#  'autotransformador tcat6-03 ou tcat6-04 de 230/138/13,8 kv - 100 mva'
#  'pelo terminal de' '138 kv']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR'
#  'VALOR_COM_UNID.MEDIDA']
# ----------
#  text:
#  energização do autotransformador tcat6-03 ou 04 230/138/13,8 kv - 100 mvapassocoordenaçãocontrolecomando/ execuçãoprocedimentoobjetivo / item de controle-o restabelecimento do autotransformador tcat6-03 ou tcat6-04 de 230/138/13,8 kv - 100 mva da se tucuruí pelo terminal de 230 kv, quando de desligamento automático, é efetuado com autonomia pela operação do agente conforme condições especificadas na io de instalação.
#  entities:
#  ['energização'
#  'autotransformador tcat6-03 ou 04 230/138/13,8 kv - 100 mvapassocoordenaçãocontrolecomando/ execuçãoprocedimentoobjetivo / item']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergizar a lt 500 kv tucuruí / xingu c1 ou c2, pelo terminal da se tucuruí.
#  entities:
#  ['desenergizar' 'lt 500 kv tucuruí / xingu c1 ou c2' 'pelo terminal da'
#  'se tucuruí']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 500 kv tucuruí / xingu c1 ou c2, pelo terminal da se xingu.
#  entities:
#  ['desenergizar' 'lt 500 kv tucuruí / xingu c1 ou c2' 'pelo terminal da'
#  'se xingu']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 500 kv tucuruí / xingu c1 ou c2 a partir da se tucuruí (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1a energização no sentido normal desta lt, quando de desligamento automático, é de autonomia da operação da se tucuruí, conforme io específica da instalação.
#  entities:
#  ['lt 500 kv tucuruí / xingu c1 ou c2' 'a partir da' 'se tucuruí'
#  'sentido normal' 'sentido normal' 'se tucuruí']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR'
#  'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  para desligamentos programados/urgência ou quando alguma condição da io específica da instalação não estiver atendida, a energização desta lt será coordenada pelo cosr-nco, conforme procedimentos a seguir:observação: estando um dos reatores de linha da lt 500 kv tucuruí / xingu a ser energizada (c1 ou c2  indisponível, esta lt não poderá ser energizada.
#  entities:
#  ['lt 500 kv tucuruí / xingu' 'não poderá ser energizada']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  1cosr-ncocosr-nco cos-cotesa (lxte energizar a lt 500 kv tucuruí / xingu c1 ou c2, pelo terminal de tucuruí.
#  entities:
#  ['lt 500 kv tucuruí' 'pelo terminal de tucuruí']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização da lt 500 kv tucuruí / xingu c1 ou c2 a partir da se xingu (sentido inverso a energização desta lt a partir da se xingu (sentido inverso  não está permitida.
#  entities:
#  ['lt 500 kv tucuruí / xingu c1 ou c2' 'a partir da' 'se xingu'
#  'sentido inverso' 'se xingu']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR'
#  'SUBESTACAO']
# ----------
#  text:
#  energização dos dois circuitos da lt 500 kv tucuruí / xingu (c1 e c2 passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controlea energização do primeiro circuito da lt 500 kv tucuruí / xingu (c1 ou c2  é coordenada e controlada pelo cosr-nco e somente poderá ser efetuada pelo terminal da se tucuruí (sentido único .
#  entities:
#  ['energização' 'lt 500 kv tucuruí / xingu (c1 ou c2' 'se tucuruí']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  estando um dos reatores de linha da lt 500 kv tucuruí / xingu c1 ou c2 indisponível, essa lt não poderá ser energizada.
#  entities:
#  ['lt 500 kv tucuruí / xingu c1 ou c2' 'não poderá ser energizada']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  1cosr-ncocosr-nco cos-cotesa (lxte energizar o primeiro circuito da lt 500 kv tucuruí / xingu c1 ou c2, pelo terminal de tucuruí.
#  entities:
#  ['lt 500 kv tucuruí' 'pelo terminal de tucuruí']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  desenergização da lt 230 kv lechuga / manaus c1 ou c2 (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-am gt (amazonas gt abrir o terminal da lt 230 kv lechuga / manaus c1 ou c2, na se manaus.
#  entities:
#  ['desenergização' 'lt 230 kv lechuga / manaus c1 ou c2'
#  'lt 230 kv lechuga / manaus c1 ou c2' 'se manaus']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  2cosr-ncocosr-ncocos-am gt (amazonas gt desenergizar a lt 230 kv lechuga / manaus c1 ou c2, pelo terminal da se lechuga.
#  entities:
#  ['desenergizar' 'lt 230 kv lechuga / manaus c1 ou c2' 'pelo terminal da'
#  'se lechuga']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv lechuga / manaus c1 ou c2 (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-am gt (amazonas gt abrir o terminal da lt 230 kv lechuga / manaus c1 ou c2, na se lechuga.
#  entities:
#  ['desenergização' 'lt 230 kv lechuga / manaus c1 ou c2'
#  'lt 230 kv lechuga / manaus c1 ou c2' 'se lechuga']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  2cosr-ncocosr-ncocos-am gt (amazonas gt desenergizar a lt 230 kv lechuga / manaus c1 ou c2, pelo terminal da se manaus.
#  entities:
#  ['desenergizar' 'lt 230 kv lechuga / manaus c1 ou c2' 'pelo terminal da']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização da lt 230 kv lechuga / manaus c1 ou c2 a partir da se manaus (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-am gt (amazonas gt energizar a lt 230 kv lechuga / manaus c1 ou c2, pelo terminal de manaus.
#  entities:
#  ['a partir da' 'se manaus' 'energizar'
#  'lt 230 kv lechuga / manaus c1 ou c2']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  energização da lt 230 kv lechuga / manaus c1 ou c2 a partir da se lechuga (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-am gt (amazonas gt energizar a lt 230 kv lechuga / manaus c1 ou c2, pelo terminal de lechuga.
#  entities:
#  ['a partir da' 'se lechuga' 'energizar'
#  'lt 230 kv lechuga / manaus c1 ou c2']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  energização dos dois circuitos da lt 230 kv lechuga / manaus (c1 e c2 passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-am gt (amazonas gt energizar o primeiro circuito da lt 230 kv lechuga / manaus (c1 ou c2 , pelo terminal de lechuga.
#  entities:
#  ['energização' 'lt 230 kv lechuga / manaus (c1 ou c2']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergização da lt 230 kv jurupari / laranjal c1 ou c2 (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-cotesa (lmte abrir o terminal da lt 230 kv jurupari / laranjal c1 ou c2, na se laranjal.
#  entities:
#  ['desenergização' 'lt 230 kv jurupari / laranjal c1 ou c2'
#  'lt 230 kv jurupari' 'se laranjal']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 230 kv jurupari / laranjal c1 ou c2, pelo terminal da se juruparí.
#  entities:
#  ['desenergizar' 'lt 230 kv jurupari / laranjal c1 ou c2'
#  'pelo terminal da' 'se juruparí']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv jurupari / laranjal c1 ou c2 (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-cotesa (lmte abrir o terminal da lt 230 kv jurupari / laranjal c1 ou c2, na se juruparí.
#  entities:
#  ['desenergização' 'lt 230 kv jurupari / laranjal c1 ou c2'
#  'lt 230 kv jurupari' 'se juruparí']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 230 kv jurupari / laranjal c1 ou c2, pelo terminal da se laranjal.
#  entities:
#  ['desenergizar' 'lt 230 kv jurupari / laranjal c1 ou c2'
#  'pelo terminal da' 'se laranjal']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  1cosr-ncocosr-nco cos-cotesa (lmte energizar a lt 230 kv jurupari / laranjal c1 ou c2, pelo terminal de juruparí.
#  entities:
#  ['energizar' 'lt 230 kv jurupari' 'pelo terminal de']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  1cosr-ncocosr-nco cos-cotesa (lmte energizar a lt 230 kv jurupari / laranjal c1 ou c2, pelo terminal de laranjal.
#  entities:
#  ['energizar' 'lt 230 kv jurupari' 'pelo terminal de']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  3cosr-ncocosr-ncocog – af energia abrir o terminal da lt 230 kv ferreira gomes / macapá, na uhe ferreira gomes.
#  entities:
#  ['abrir o terminal' 'lt 230 kv ferreira gomes / macapá'
#  'uhe ferreira gomes']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'USINA']
# ----------
#  text:
#  1cosr-ncocosr-nco cog – af energia energizar a lt 230 kv ferreira gomes / macapá, pelo terminal da se macapá.
#  entities:
#  ['energizar a' 'lt 230 kv ferreira']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergizar a lt 500 kv juruparí / xingu c1 ou c2, pelo terminal da se xingu.
#  entities:
#  ['desenergizar' 'lt 500 kv juruparí / xingu c1 ou c2' 'pelo terminal da'
#  'se xingu']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 500 kv juruparí / xingu c1 ou c2, pelo terminal da se juruparí.
#  entities:
#  ['desenergizar' 'lt 500 kv juruparí / xingu c1 ou c2' 'pelo terminal da'
#  'se juruparí']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  1cosr-ncocosr-nco cos-cotesa (lxte energizar a lt 500 kv juruparí / xingu c1 ou c2, pelo terminal de xingu.
#  entities:
#  ['lt 500 kv juruparí' 'pelo terminal de']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização da lt 500 kv jurupari / xingu c1 ou c2 a partir da se jurupari (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1a energização desta lt a partir da se juruparí (sentido inverso  será controlada pelo cosr-nco, de acordo com os seguintes procedimentos:observação: estando um dos reatores de linha da lt 500 kv juruparí / xingu a ser energizada (c1 ou c2  indisponível, esta lt não poderá ser energizada.
#  entities:
#  ['a partir da' 'se jurupari' 'se juruparí' 'lt 500 kv juruparí / xingu'
#  'não poderá ser energizada']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'SUBESTACAO' 'EQUIPAMENTO'
#  'ACAO_A_EXECUTAR']
# ----------
#  text:
#  1cosr-ncocosr-nco cos-cotesa (lmte energizar a lt 500 kv jurupari / oriximiná c1 ou c2, pelo terminal de juruparí.
#  entities:
#  ['lt 500 kv jurupari' 'pelo terminal de']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização da lt 500 kv jurupari / oriximiná c1 ou c2 a partir da se oriximiná (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1a energização desta lt a partir da se oriximiná (sentido inverso  será controlada pelo cosr-nco, de acordo com os seguintes procedimentos:observação: estando um dos reatores de linha da lt 500 kv juruparí / oriximiná a ser energizada (c1 ou c2  indisponível, esta lt não poderá ser energizada.
#  entities:
#  ['a partir da' 'se oriximiná' 'se oriximiná' 'sentido inverso'
#  'lt 500 kv juruparí / oriximiná' 'não poderá ser energizada']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'SUBESTACAO' 'ACAO_A_EXECUTAR'
#  'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  1cosr-ncocosr-nco cos-cotesa (lmte energizar a lt 500 kv jurupari / oriximiná c1 ou c2, pelo terminal da se oriximiná.
#  entities:
#  ['lt 500 kv jurupari' 'pelo terminal da' 'se oriximiná']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 500 kv oriximiná / silves c1 ou c2, pelo terminal da se oriximiná.
#  entities:
#  ['desenergizar' 'lt 500 kv oriximiná' 'pelo terminal da' 'se oriximiná']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 500 kv oriximiná / silves c1 ou c2, pelo terminal da se silves.
#  entities:
#  ['desenergizar' 'lt 500 kv oriximiná' 'pelo terminal da' 'se silves']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 500 kv oriximiná / silves c1 ou c2 a partir da se oriximiná (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1a energização no sentido normal desta lt, quando de desligamento automático, é de autonomia da operação da se oriximiná, conforme io específica da instalação.
#  entities:
#  ['lt 500 kv oriximiná' 'a partir da' 'se oriximiná' 'sentido normal'
#  'sentido normal' 'se oriximiná']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR'
#  'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  para desligamentos programados/urgência ou quando alguma condição da io específica da instalação não estiver atendida, a energização desta lt será coordenada pelo cosr-nco, conforme procedimentos a seguir:observação: estando um dos reatores de linha da lt 500 kv oriximiná / silves a ser energizada (c1 ou c2  indisponível, esta lt não poderá ser energizada.
#  entities:
#  ['lt 500 kv oriximiná / silves' 'não poderá ser energizada']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  1cosr-ncocosr-nco cos-evoltz (mte energizar a lt 500 kv oriximiná / silves c1 ou c2, pelo terminal de oriximiná.
#  entities:
#  ['lt 500 kv oriximiná' 'pelo terminal de']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização da lt 500 kv oriximiná / silves c1 ou c2 a partir da se oriximiná (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1a energização desta lt a partir da se oriximiná (sentido inverso  será controlada pelo cosr-nco, de acordo com os seguintes procedimentos:observação: estando um dos reatores de linha da lt 500 kv oriximiná / silves a ser energizada (c1 ou c2  indisponível, esta lt não poderá ser energizada.
#  entities:
#  ['lt 500 kv oriximiná' 'a partir da' 'se oriximiná' 'se oriximiná'
#  'sentido inverso' 'lt 500 kv oriximiná / silves'
#  'não poderá ser energizada']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'SUBESTACAO'
#  'ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  desenergização da lt 230 kv balbina / lechuga (sentido normal passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1 cosr-nco verificar a necessidade de adequações no sistema, para atendimento às limitações impostas pela indisponibilidade da lt 230 kv balbina / lechuga, conforme definido na io-oc.n.5mm.
#  entities:
#  ['desenergização' 'lt 230 kv balbina / lechuga' 'verificar']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  3cosr-ncocosr-ncocos-am gt (amazonas gt desenergizar a lt 230 kv balbina / lechuga, pelo terminal da se balbina.
#  entities:
#  ['desenergizar' 'lt 230 kv balbina / lechuga' 'se balbina']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv balbina / lechuga (sentido inverso passocoordenaçãocontrolecomando/ execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-am gt (amazonas gt abrir o terminal da lt 230 kv balbina / lechuga, na se balbina.
#  entities:
#  ['desenergização' 'lt 230 kv balbina / lechuga'
#  'lt 230 kv balbina / lechuga,' 'se balbina']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  2cosr-ncocosr-ncocos-evoltz (mte desenergizar a lt 230 kv balbina / lechuga, pelo terminal da se lechuga.
#  entities:
#  ['desenergizar' 'lt 230 kv balbina / lechuga' 'se lechuga']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 230 kv balbina / lechuga a partir da se balbina (sentido normal passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-am gt (amazonas gt energizar a lt 230 kv balbina / lechuga, pelo terminal de balbina.com os dois reatores de linha do terminal da se lechuga desconectados:- tensão na se balbina ≤ 235 kv.
#  entities:
#  ['se balbina' 'sentido normal' 'energizar' 'lt 230 kv balbina / lechuga'
#  'se balbina' '≤' '235 kv']
#  types:
#  ['SUBESTACAO' 'ACAO_A_EXECUTAR' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO'
#  'SUBESTACAO' 'OPERADOR_MATEMATICO' 'VALOR_COM_UNID.MEDIDA']
# ----------
#  text:
#  observação:estando a lt 230 kv balbina / cristiano rocha ou a lt 230 kv cristiano rocha / lechuga indisponível, a energização da lt 230 kv balbina / lechuga deverá ser efetuada conforme segue:- preferencialmente a partir da se lechuga (sentido inverso .
#  entities:
#  ['lt 230 kv balbina / cristiano rocha' 'lt 230 kv cristiano rocha /'
#  'a partir da' 'se lechuga']
#  types:
#  ['EQUIPAMENTO' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv balbina / cristiano rocha (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-am gt(amazonas gt abrir o terminal da lt 230 kv balbina / cristiano rocha, na se cristiano rocha.
#  entities:
#  ['desenergização' 'lt 230 kv balbina / cristiano rocha' 'sentido normal'
#  'lt 230 kv balbina / cristiano rocha' 'se cristiano rocha']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO'
#  'SUBESTACAO']
# ----------
#  text:
#  2cosr-ncocosr-ncocos-am gt (amazonas gt desenergizar a lt 230 kv balbina / cristiano rocha, pelo terminal da se balbina.
#  entities:
#  ['desenergizar' 'lt 230 kv balbina / cristiano rocha' 'pelo terminal da'
#  'se balbina']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv balbina / cristiano rocha (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-am gt (amazonas gt abrir o terminal da lt 230 kv balbina / cristiano rocha, na se balbina.
#  entities:
#  ['desenergização' 'lt 230 kv balbina / cristiano rocha'
#  'lt 230 kv balbina / cristiano rocha' 'se balbina']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  2cosr-ncocosr-ncocos-am gt (amazonas gt desenergizar a lt 230 kv balbina / cristiano rocha, pelo terminal da se cristiano rocha.
#  entities:
#  ['desenergizar' 'lt 230 kv balbina / cristiano rocha'
#  'pelo terminal da se cristiano rocha']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização da lt 230 kv balbina / cristiano rocha a partir da se balbina (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-nco cos-am gt (amazonas gt energizar a lt 230 kv balbina / cristiano rocha, pelo terminal de balbina.
#  entities:
#  ['a partir da' 'se balbina' 'energizar'
#  'lt 230 kv balbina / cristiano rocha']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  energização da lt 230 kv balbina / cristiano rocha a partir da se cristiano rocha (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-nco cos-am gt (amazonas gt energizar a lt 230 kv balbina / cristiano rocha, pelo terminal de cristiano rocha.
#  entities:
#  ['a partir da' 'se cristiano rocha' 'sentido inverso' 'energizar'
#  'lt 230 kv balbina / cristiano rocha' 'pelo terminal de']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR' 'ACAO_A_EXECUTAR'
#  'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  desenergização da lt 230 kv cristiano rocha / lechuga (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-am gt (amazonas gt abrir o terminal da lt 230 kv cristiano rocha / lechuga, na se cristiano rocha.
#  entities:
#  ['desenergização' 'lt 230 kv cristiano rocha / lechuga'
#  'lt 230 kv cristiano rocha / lechuga, na se cristiano rocha']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO']
# ----------
#  text:
#  2cosr-ncocosr-ncocos-evoltz (mte desenergizar a lt 230 kv cristiano rocha / lechuga, pelo terminal da se lechuga.
#  entities:
#  ['desenergizar' 'lt 230 kv cristiano rocha' 'se lechuga']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv cristiano rocha / lechuga (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-evoltz (mte abrir o terminal da lt 230 kv cristiano rocha / lechuga, na se lechuga.
#  entities:
#  ['desenergização' 'lt 230 kv cristiano rocha / lechuga'
#  'lt 230 kv cristiano rocha / lechuga,' 'se lechuga']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  2cosr-ncocosr-ncocos-am gt (amazonas gt  desenergizar a lt 230 kv cristiano rocha / lechuga, pelo terminal da se cristiano rocha.
#  entities:
#  ['desenergizar' 'lt 230 kv cristiano rocha / lechuga' 'se cristiano rocha']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 230 kv cristiano rocha / lechuga a partir da se lechuga (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-nco cos-evoltz (mte energizar a lt 230 kv cristiano rocha / lechuga, pelo terminal de lechuga.
#  entities:
#  ['lt 230 kv cristiano rocha' 'se lechuga' 'energizar'
#  'lt 230 kv cristiano rocha / lechuga']
#  types:
#  ['EQUIPAMENTO' 'SUBESTACAO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  energização da lt 230 kv cristiano rocha / lechuga a partir da se cristiano rocha (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-nco cos-am gt (amazonas gt  (amazonas gt energizar a lt 230 kv cristiano rocha / lechuga, pelo terminal de cristiano rocha.
#  entities:
#  ['lt 230 kv cristiano rocha' 'a partir da' 'se cristiano rocha'
#  'sentido inverso' 'energizar' 'lt 230 kv cristiano rocha / lechuga']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR'
#  'ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergização da lt 230 kv porto velho / abunã c1 (sentido normal passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronorteabrir o terminal da lt 230 kv porto velho / abunã c1, na se abunã.
#  entities:
#  ['desenergização' 'lt 230 kv porto velho / abunã c1' 'sentido normal'
#  'lt 230 kv porto velho / abunã c1' 'se abunã']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO'
#  'SUBESTACAO']
# ----------
#  text:
#  observação:para a desenergização do circuito c1 da lt 230 kv porto velho / abunã, confirmar aberto o terminal de 230 kv do transformador 230/69 kv, que está conectado nessa lt.
#  entities:
#  ['desenergização' 'lt 230 kv porto velho / abunã' '230 kv'
#  'transformador 230/69 kv']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'VALOR_COM_UNID.MEDIDA' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergizar a lt 230 kv porto velho / abunã c1, pelo terminal da se porto velho.
#  entities:
#  ['desenergizar' 'lt 230 kv porto velho / abunã c1' 'pelo terminal da'
#  'se porto velho']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv porto velho / abunã c1 (sentido inverso passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronorteabrir o terminal da lt 230 kv porto velho / abunã c1 ou c2, na se porto velho.
#  entities:
#  ['desenergização' 'lt 230 kv porto velho / abunã c1'
#  'lt 230 kv porto velho / abunã c1 ou c2' 'se porto velho']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  observação:para a desenergização do circuito c1 da lt 230 kv porto velho / abunã, confirmar aberto o terminal de 230 kv do transformador 230/69 kv, que está conectado nessa lt.
#  entities:
#  ['desenergização' 'lt 230 kv porto velho / abunã' '230 kv'
#  'transformador 230/69 kv']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'VALOR_COM_UNID.MEDIDA' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergizar a lt 230 kv porto velho / abunã c1 ou c2, pelo terminal da se abunã.
#  entities:
#  ['desenergizar' 'lt 230 kv porto velho / abunã c1 ou c2'
#  'pelo terminal da' 'se abunã']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 230 kv porto velho / abunã c1 a partir da se porto velho (sentido normal passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronorteenergizar a lt 230 kv porto velho / abunã c1, pela se porto velho.
#  entities:
#  ['lt 230 kv porto velho / abunã c1' 'a partir da' 'se porto velho'
#  'sentido normal' 'lt 230 kv porto velho / abunã c1' 'se porto velho']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR'
#  'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  observação:para a energização do circuito c1 da lt 230 kv porto velho / abunã, confirmar aberto o terminal de 230 kv do transformador 230/69 kv, que está conectado nessa lt, para alimentação do canteiro de obras da uhe jirau.
#  entities:
#  ['energização' 'lt 230 kv porto velho / abunã' '230 kv'
#  'transformador 230/69 kv']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'VALOR_COM_UNID.MEDIDA' 'EQUIPAMENTO']
# ----------
#  text:
#  energização da lt 230 kv porto velho / abunã c1 a partir da se abunã (sentido inverso passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle-é proibida a energização, no sentido inverso, do circuito 1 da lt 230 kv porto velho / abunã na indisponibilidade de seu reator de linha.
#  entities:
#  ['lt 230 kv porto velho / abunã c1' 'a partir da' 'se abunã'
#  'sentido inverso' 'lt 230 kv porto velho / abunã' 'reator de linha']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR'
#  'EQUIPAMENTO' 'EQUIPAMENTO']
# ----------
#  text:
#  observação:para a energização do circuito c1 da lt 230 kv porto velho / abunã, confirmar aberto o terminal de 230 kv do transformador 230/69 kv, que está conectado nessa lt, para alimentação do canteiro de obras da uhe jirau.
#  entities:
#  ['energização' 'lt 230 kv porto velho / abunã' '230 kv'
#  'transformador 230/69 kv']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'VALOR_COM_UNID.MEDIDA' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergização da lt 230 kv porto velho / abunã c2 (sentido normal passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronorteabrir o terminal da lt 230 kv porto velho / abunã c2, na se abunã.
#  entities:
#  ['desenergização' 'lt 230 kv porto velho / abunã c2'
#  'lt 230 kv porto velho / abunã c2' 'se abunã']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 230 kv porto velho / abunã c2, pelo terminal da se porto velho.
#  entities:
#  ['desenergizar' 'lt 230 kv porto velho / abunã c2' 'pelo terminal da'
#  'se porto velho']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv porto velho / abunã c2 (sentido inverso passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronorteabrir o terminal da lt 230 kv porto velho / abunã c2, na se porto velho.
#  entities:
#  ['desenergização' 'lt 230 kv porto velho / abunã c2'
#  'lt 230 kv porto velho / abunã c2' 'se porto velho']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 230 kv porto velho / abunã c2, pelo terminal da se abunã.
#  entities:
#  ['desenergizar' 'lt 230 kv porto velho / abunã c2' 'pelo terminal da'
#  'se abunã']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 230 kv porto velho / abunã c2 a partir da se porto velho (sentido normal passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle-é proibida a energização do circuito 2 da lt 230 kv porto velho / abunã na indisponibilidade de seu reator de linha.
#  entities:
#  ['lt 230 kv porto velho / abunã' 'a partir da' 'se porto velho'
#  'sentido normal' 'lt 230 kv porto velho / abunã' 'reator de linha']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR'
#  'EQUIPAMENTO' 'EQUIPAMENTO']
# ----------
#  text:
#  energização da lt 230 kv porto velho / abunã c2 a partir da se abunã (sentido inverso passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle-é proibida a energização do circuito 2 da lt 230 kv porto velho / abunã na indisponibilidade de seu reator de linha.
#  entities:
#  ['lt 230 kv porto velho / abunã' 'a partir da' 'se abunã'
# ...
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  2cosr-ncocosr-ncocatxerê (cos-state grid energizar a lt 500 kv ribeirãozinho / cuiabá c2, pelo terminal de ribeirãozinho.
#  entities:
#  ['energizar' 'lt 500 kv ribeirãozinho' 'pelo terminal de']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  desenergização da lt 230 kv brasnorte / juína c1 ou c2 (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoagentes de geraçãoadequar o fluxo f(da-ji c1 +f(da-ji c2  para um valor inferior ao da atuação do esquema de corte de geração na uhe dardanelos.
#  entities:
#  ['desenergização' 'lt 230 kv brasnorte' 'uhe dardanelos']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'USINA']
# ----------
#  text:
#  desenergizar a lt 230 kv brasnorte / juína c1 ou c2, pelo terminal da se brasnorte.
#  entities:
#  ['desenergizar' 'lt 230 kv brasnorte / juína c1 ou c2'
#  'pelo terminal da se brasnorte']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  desenergização da lt 230 kv brasnorte / juína c1 ou c2 (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle-a desenergização da lt 230 kv brasnorte / juína c1 ou c2 (sentido inverso  só deverá ser realizada quando de indisponibilidade do reator de linha dessa lt do terminal da se juína.
#  entities:
#  ['desenergização' 'lt 230 kv brasnorte' 'desenergização'
#  'lt 230 kv brasnorte / juína c1 ou c2']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  f(da-ji c1 +f(da-ji c2  &lt; 260 mw2cosr-ncocosr-ncoebte(cot – tbe sul abrir o terminal da lt 230 kv brasnorte / juína c1 ou c2, na se brasnorte.
#  entities:
#  ['lt 230 kv brasnorte' 'na se brasnorte']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  desenergizar a lt 230 kv brasnorte / juína c1 ou c2, pelo terminal da se brasnorte.
#  entities:
#  ['desenergizar' 'lt 230 kv brasnorte / juína c1 ou c2'
#  'pelo terminal da se brasnorte']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização da lt 230 kv brasnorte / juína (c1 ou c2  a partir da se brasnorte (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoebte (cot – tbe sul energizar a lt 230 kv brasnorte / juína (c1 ou c2 , pelo terminal da se brasnorte.
#  entities:
#  ['lt 230 kv brasnorte / juína (c1 ou c2' 'a partir da' 'sentido normal'
#  'energizar' 'lt 230 kv brasnorte' 'pelo terminal da se brasnorte']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'ACAO_A_EXECUTAR' 'ACAO_A_EXECUTAR'
#  'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização da lt 230 kv brasnorte / juína c1 ou c2 a partir da se juína (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle-a energização da lt 230 kv brasnorte / juína c1 ou c2, a partir do terminal da se juína (sentido inverso  deverá ser realizada quando de indisponibilidade do reator de linha dessa lt do terminal da se juína.
#  entities:
#  ['lt 230 kv brasnorte' 'a partir da' 'a partir do terminal da' 'se juína']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  neste caso adotar os seguintes procedimentos:1cosr-ncocosr-ncoebte (cot – tbe sul energizar a lt 230 kv brasnorte / juína (c1 ou c2 , pelo terminal da se juína.
#  entities:
#  ['energizar' 'lt 230 kv brasnorte / juína (c1 ou c2' 'pelo terminal da']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  fechar o terminal da lt 230 kv brasnorte / juína (c1 ou c2 , na se brasnorte.
#  entities:
#  ['lt 230 kv brasnorte / juína (c1 ou c2' 'na se brasnorte']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização do primeiro circuito da lt 230 kv brasnorte / juína a partir da se brasnorte (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoebte (cot-tbe sul energizar o primeiro circuito da lt 230 kv brasnorte / juína (c1 ou c2 , pelo terminal da se brasnorte.
#  entities:
#  ['energização' 'lt 230 kv brasnorte / juína' 'a partir da'
#  'sentido normal' 'energizar' 'lt 230 kv brasnorte'
#  'pelo terminal da se brasnorte']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'ACAO_A_EXECUTAR'
#  'ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  v ≤ 23 kv δ ≤ 20º f ≤ 0,20 hz4cosr-ncocosr-ncoebte (cot-tbe sul energizar o segundo circuito da lt 230 kv brasnorte / juína.
#  entities:
#  ['v' '≤' '23 kv' '0,20 hz4cosr-ncocosr-ncoebte' 'energizar'
#  'lt 230 kv brasnorte']
#  types:
#  ['VALOR_COM_UNID.MEDIDA' 'OPERADOR_MATEMATICO' 'VALOR_COM_UNID.MEDIDA'
#  'VALOR_COM_UNID.MEDIDA' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  energização do primeiro circuito da lt 230 kv brasnorte / juína a partir da se juína (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle-a energização do primeiro circuito da lt 230 kv brasnorte / juína (c1 ou c2 , pelo terminal da se juína (sentido inverso  não é permitida.
#  entities:
#  ['energização' 'lt 230 kv brasnorte / juína' 'a partir da'
#  'lt 230 kv brasnorte / juína (c1 ou c2' 'pelo terminal da' 'se juína']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO'
#  'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergização da lt 230 kv dardanelos / juína c1 ou c2 (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoagentes de geraçãoadequar o fluxo f(da-ji c1 +f(da-ji c2  para um valor inferior ao da atuação do esquema de corte de geração na uhe dardanelos.
#  entities:
#  ['desenergização' 'lt 230 kv dardanelos / juína c1 ou c2' 'uhe dardanelos']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'USINA']
# ----------
#  text:
#  desenergizar a lt 230 kv dardanelos / juína c1 ou c2, pelo terminal da uhe dardanelos.
#  entities:
#  ['desenergizar' 'lt 230 kv dardanelos / juína c1 ou c2' 'pelo terminal da']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  desenergização da lt 230 kv dardanelos / juína c1 ou c2 (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle-a desenergização da lt 230 kv dardanelos / juína c1 ou c2 (sentido inverso  só é permitida estando a uhe dardanelos com todas as suas unidades geradoras desligadas.
#  entities:
#  ['desenergização' 'lt 230 kv dardanelos / juína c1 ou c2' 'desenergização'
#  'lt 230 kv dardanelos / juína c1 ou c2']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  energização da lt 230 kv dardanelos / juína (c1 ou c2  a partir da se dardanelos (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoáguas da pedra (cos-neoenergia energizar a lt 230 kv dardanelos / juína (c1 ou c2 , pelo terminal da se dardanelos.
#  entities:
#  ['a partir da' 'se dardanelos' 'sentido normal' 'lt 230 kv dardanelos'
#  'pelo terminal da']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO'
#  'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização do primeiro circuito da lt 230 kv dardanelos / juína a partir da se juína (sentido único passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoáguas da pedra (cos-neoenergia configurar a se dardanelos de forma que o reator de barra dare6-01 de 20 mvar dessa se seja energizado simultaneamente com a lt 230 kv dardanelos / juína (preferencialmente o circuito c1 em função da configuração de operação normal da uhe/se dardanelos .
#  entities:
#  ['energização' 'lt 230 kv dardanelos' 'a partir da' 'reator de barra'
#  '20 mvar' 'lt 230 kv dardanelos / juína']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO'
#  'VALOR_COM_UNID.MEDIDA' 'EQUIPAMENTO']
# ----------
#  text:
#  2cosr-ncocosr-ncoáguas da pedra (cos-neoenergia energizar o primeiro circuito da lt 230 kv dardanelos / juína (c1 ou c2 , pelo terminal da se juína.
#  entities:
#  ['energizar' 'lt 230 kv dardanelos / juína (c1 ou c2' 'pelo terminal da']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  3cosr-ncocosr-ncoeletronorte (oeort desenergizar a lt 230 kv manso / nobres, pelo terminal da se nobres.
#  entities:
#  ['lt 230 kv manso / nobres' 'pelo terminal da se nobres']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização da lt 230 kv manso / nobres a partir da se nobres (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncoeletronorte (oeort energizar a lt 230 kv manso / nobres, pelo terminal da se nobres.
#  entities:
#  ['a partir da se nobres' 'sentido normal' 'lt 230 kv manso / nobres'
#  'pelo terminal da se nobres']
#  types:
#  ['ACAO_A_EXECUTAR' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  energização da lt 230 kv manso / nobres a partir da uhe manso (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncofurnas (ctrg energizar a lt 230 kv manso / nobres, pelo terminal da uhe manso.
#  entities:
#  ['a partir da' 'lt 230 kv manso / nobres' 'pelo terminal da' 'uhe manso']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 230 kv canarana / paranatinga, pelo terminal da se paranatinga.
#  entities:
#  ['desenergizar' 'lt 230 kv canarana / paranatinga'
#  'pelo terminal da se paranatinga']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  3cosr-ncocosr-ncocnte(cos-state grid energizar a lt 230 kv canarana / paranatinga, pelo terminal da se paranatinga.
#  entities:
#  ['energizar' 'lt 230 kv canarana / paranatinga'
#  'pelo terminal da se paranatinga']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  desenergizar a lt 500 kv cuiabá / jauru c1 ou c2, pelo terminal da se cuiabá.
#  entities:
#  ['desenergizar' 'lt 500 kv cuiabá / jauru c1 ou c2' 'pelo terminal da'
#  'se cuiabá']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 500 kv cuiabá / jauru c1 ou c2, pelo terminal da se jauru.
#  entities:
#  ['desenergizar' 'lt 500 kv cuiabá / jauru c1 ou c2' 'pelo terminal da'
#  'se jauru']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 500 kv cuiabá / jauru c1, pelo terminal da se cuiabá.
#  entities:
#  ['desenergizar' 'lt 500 kv cuiabá / jauru c1' 'pelo terminal da'
#  'se cuiabá']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 500 kv cuiabá / jauru c1 ou c2 a partir da se cuiabá (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncotme (cor-c  / c1slte (cos-cotesa  / c2energizar a lt 500 kv cuiabá / jauru c1 ou c2, pelo terminal da se cuiabá.
#  entities:
#  ['lt 500 kv cuiabá' 'a partir da' 'se cuiabá' 'sentido normal'
#  'lt 500 kv cuiabá / jauru c1 ou c2' 'pelo terminal da' 'se cuiabá']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR'
#  'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  energização da lt 500 kv cuiabá / jauru c1 ou c2 a partir da se jauru (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncotme (cor-c  / c1slte (cos-cotesa  / c2energizar a lt 500 kv cuiabá / jauru c1 ou c2, pelo terminal da se jauru.
#  entities:
#  ['lt 500 kv cuiabá' 'a partir da' 'se jauru'
#  'lt 500 kv cuiabá / jauru c1 ou c2' 'pelo terminal da' 'se jauru']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO' 'EQUIPAMENTO'
#  'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 500 kv teles pires / paranaíta c1 ou c2, pelo terminal da uhe/se teles pires.
#  entities:
#  ['desenergizar' 'lt 500 kv teles pires / paranaíta c1 ou c2'
#  'pelo terminal da' 'se teles pires']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  2 cosr-ncoteles pires (cos-neoenergia desligar ou manter desligado o religamento automático tripolar da lt 500 kv teles pires / paranaíta remanescente.
#  entities:
#  ['desligar' 'religamento automático tripolar']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  a partir da uhe/se teles pires (sentido normal passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-nco teles pires(cos-neoenergia energizar a lt 500 kv teles pires / paranaíta c1 ou c2, pelo terminal da uhe/se teles pires.
#  entities:
#  ['a partir da' 'se teles pires'
#  'lt 500 kv teles pires / paranaíta c1 ou c2' 'pelo terminal da'
#  'se teles pires']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR'
#  'SUBESTACAO']
# ----------
#  text:
#  a partir da se paranaíta (sentido inverso passocoordenaçãocontrolecomando /execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-nco teles pires(cos-neoenergia energizar a lt 500 kv teles pires / paranaíta c1 ou c2, pelo terminal da se paranaíta.
#  entities:
#  ['a partir da' 'se paranaíta' 'lt 500 kv teles pires / paranaíta c1 ou c2'
#  'pelo terminal da' 'se paranaíta']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR'
#  'SUBESTACAO']
# ----------
#  text:
#  desenergizar a lt 500 kv cláudia / paranatinga c1 ou c3, pelo terminal da se paranatinga.
#  entities:
#  ['desenergizar' 'lt 500 kv cláudia / paranatinga c1 ou c3']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO']
# ----------
#  text:
#  desenergizar a lt 500 kv cláudia / paranatinga c1 ou c3, pelo terminal da se cláudia.
#  entities:
#  ['desenergizar' 'lt 500 kv cláudia / paranatinga c1 ou c3' 'se cláudia']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'SUBESTACAO']
# ----------
#  text:
#  a partir da se paranatinga (sentido normal passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controleestando um dos reatores de linha da lt 500 kv cláudia / paranatinga c1 ou c3 indisponível, essa lt não poderá ser energizada.
#  entities:
#  ['a partir da se paranatinga' 'sentido normal'
#  'um dos reatores de linha da lt 500 kv cláudia / paranatinga c1 ou c3'
#  'não poderá ser energizada']
#  types:
#  ['ACAO_A_EXECUTAR' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR']
# ----------
#  text:
#  a partir da se cláudia (sentido inverso passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controleestando um dos reatores de linha da lt 500 kv cláudia / paranatinga c1 ou c3 indisponível, essa lt não poderá ser energizada.
#  entities:
#  ['a partir da' 'se cláudia' 'sentido inverso'
#  'um dos reatores de linha da lt 500 kv cláudia'
#  'não poderá ser energizada']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO'
#  'ACAO_A_EXECUTAR']
# ----------
#  text:
#  desenergizar a lt 500 kv cláudia / sinop, pelo terminal da se sinop.
#  entities:
#  ['desenergizar' 'lt 500 kv cláudia / sinop' 'pelo terminal da' 'se sinop']
#  types:
#  ['ACAO_A_EXECUTAR' 'EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  a partir da se cláudia (sentido normal  passocoordenaçãocontrolecomando / execuçãoprocedimentoobjetivo / item de controle1cosr-ncocosr-ncocos-state gridenergizar a lt 500 kv cláudia / sinop, pelo terminal da se cláudia.
#  entities:
#  ['a partir da' 'se cláudia' 'sentido normal' 'lt 500 kv cláudia / sinop'
#  'pelo terminal da' 'se cláudia']
#  types:
#  ['ACAO_A_EXECUTAR' 'SUBESTACAO' 'ACAO_A_EXECUTAR' 'EQUIPAMENTO'
#  'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
#  text:
#  1cosr-ncocosr-ncocos-state gridenergizar a lt 500 kv cláudia / sinop, pelo terminal da se sinop.
#  entities:
#  ['lt 500 kv cláudia / sinop' 'pelo terminal da' 'se sinop']
#  types:
#  ['EQUIPAMENTO' 'ACAO_A_EXECUTAR' 'SUBESTACAO']
# ----------
