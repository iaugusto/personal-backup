# %% [markdown]
# # Ground Truth Entity Recognition

# %%
# %pip install awswrangler
# %pip install bleach
# %pip install nltk

# %%
import os
import sys
import nltk
import json
import boto3 
import numpy as np
import pandas as pd
import awswrangler as wr
from bleach.sanitizer import Cleaner

nltk.download('punkt')

from sagemaker import get_execution_role
role = get_execution_role()

sys.path.append(os.path.dirname(os.getcwd()) + '/src')
print('added ', os.path.dirname(os.getcwd()) + '/src', ' to sys.')
from preprocess import preprocess_data
# Out:
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# added  /home/ec2-user/SageMaker/ons-poc-manobras-catalog/src  to sys.
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
preproc = preprocess_data()
# Out:
# Preprocessing module
# started at  2021-10-14 20:41:27.664160

# %%
# reading file contents from s3 bucket
df = preproc.get_baseline_text()
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6025 entries, 0 to 6024
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Id                       6025 non-null   int64
#  1   documentUID              6025 non-null   object
#  2   contentUID               6025 non-null   object
#  3   Title                    6023 non-null   object
#  4   Level                    6025 non-null   object
#  5   hierarquia               6025 non-null   object
#  6   relatedEmbedded          0 non-null      float64
#  7   relatedLinks             0 non-null      float64
#  8   MpoAreaEletrica          6025 non-null   object
#  9   MpoCentro                6025 non-null   object
#  10  MpoEquipamentos          2370 non-null   object
#  11  MpoIdentificador         6025 non-null   object
#  12  MpoLigadoDesligado       6025 non-null   object
#  13  MpoLocalizacaoTaxonomia  6025 non-null   object
#  14  MpoMopsAssociadas        1418 non-null   object
#  15  MpoMopsAssociadasUrl     1418 non-null   object
#  16  MpoRevisaoReadOnly       6025 non-null   int64
#  17  MpoSubmodulo             6025 non-null   object
#  18  MpoTema                  5870 non-null   object
#  19  MpoTextoVigenciaPorData  6025 non-null   object
#  20  MpoTipoDocumento         6025 non-null   object
#  21  nomeDocumento            5522 non-null   object
#  22  statusItem               6025 non-null   object
#  23  StatusDocumento          6025 non-null   object
#  24  texto                    6025 non-null   object
#  25  Created                  6025 non-null   object
# dtypes: float64(2), int64(2), object(22)
# memory usage: 1.2+ MB
# None
#        Id                           documentUID  \
# 0  181505  e401f716-b9c8-44cf-a961-75dd62a2a8aa
# 1  181506  e401f716-b9c8-44cf-a961-75dd62a2a8aa
# 2  181507  e401f716-b9c8-44cf-a961-75dd62a2a8aa
# 3  181508  e401f716-b9c8-44cf-a961-75dd62a2a8aa
# 4  181509  e401f716-b9c8-44cf-a961-75dd62a2a8aa
#
#                              contentUID  \
# 0  cffb9a6b-ba1f-4756-82d4-cd88a5230036
# 1  7b8fcaee-0dce-41f1-b1d9-3dacc9871960
# 2  5a57338c-7b88-466c-a769-51ce87e128b1
# 3  2d387a90-353d-4411-b263-d528fbba8e7c
# 4  0ba555c0-1b6a-4d16-8f76-8758b214042c
#
#                                                Title Level  \
# 0                                           OBJETIVO     1
# 1                               CONSIDERAÇÕES GERAIS     2
# 2  PREPARAÇÃO PARA MANOBRAS DE LINHAS DE TRANSMISSÃO     3
# 3                       LT 230 KV Tucuruí / Altamira   3.1
# 4                         LT 230 KV Altamira / Xingu   3.2
#
#                                           hierarquia  relatedEmbedded  \
# 0                                           OBJETIVO              NaN
# 1                               CONSIDERAÇÕES GERAIS              NaN
# 2  PREPARAÇÃO PARA MANOBRAS DE LINHAS DE TRANSMISSÃO              NaN
# 3  3 - PREPARAÇÃO PARA MANOBRAS DE LINHAS DE TRAN...              NaN
# 4  3 - PREPARAÇÃO PARA MANOBRAS DE LINHAS DE TRAN...              NaN
#
#    relatedLinks MpoAreaEletrica MpoCentro  ... MpoRevisaoReadOnly  \
# 0           NaN             2TR  COSR-NCO  ...                 27
# 1           NaN             2TR  COSR-NCO  ...                 27
# 2           NaN             2TR  COSR-NCO  ...                 27
# 3           NaN             2TR  COSR-NCO  ...                 27
# 4           NaN             2TR  COSR-NCO  ...                 27
#
#                                         MpoSubmodulo  \
# 0  5.12 - Preparação para Manobras na Área 230 kV...
# 1  5.12 - Preparação para Manobras na Área 230 kV...
# 2  5.12 - Preparação para Manobras na Área 230 kV...
# 3  5.12 - Preparação para Manobras na Área 230 kV...
# 4  5.12 - Preparação para Manobras na Área 230 kV...
#
#                                              MpoTema MpoTextoVigenciaPorData  \
# 0  Instruções da Região Norte - Área 230 kV Tramo...     2020-03-11 03:00:00
# 1  Instruções da Região Norte - Área 230 kV Tramo...     2020-03-11 03:00:00
# 2  Instruções da Região Norte - Área 230 kV Tramo...     2020-03-11 03:00:00
# 3  Instruções da Região Norte - Área 230 kV Tramo...     2020-03-11 03:00:00
# 4  Instruções da Região Norte - Área 230 kV Tramo...     2020-03-11 03:00:00
#
#            MpoTipoDocumento  \
# 0  Preparação para Manobras
# 1  Preparação para Manobras
# 2  Preparação para Manobras
# 3  Preparação para Manobras
# 4  Preparação para Manobras
#
#                                        nomeDocumento  statusItem  \
# 0  Preparação para Manobras na Área 230 kV Tramo ...    Aprovado
# 1  Preparação para Manobras na Área 230 kV Tramo ...    Aprovado
# 2  Preparação para Manobras na Área 230 kV Tramo ...    Aprovado
# 3  Preparação para Manobras na Área 230 kV Tramo ...    Aprovado
# 4  Preparação para Manobras na Área 230 kV Tramo ...    Aprovado
#
#   StatusDocumento                                              texto  \
# 0         Vigente  Estabelecer procedimentos para manobras de equ...
# 1         Vigente  2.1.            Os procedimentos contidos nest...
# 2         Vigente   1. OBJETIVO2....................................
# 3         Vigente  3.1.1.       Desenergização da LT 230 kV Tucur...
# 4         Vigente  3.2.1.       Desenergização da LT 230 kV Altam...
#
#                Created
# 0  30/07/2021 14:43:17
# 1  30/07/2021 14:43:18
# 2  30/07/2021 14:43:18
# 3  30/07/2021 14:43:18
# 4  30/07/2021 14:43:18
#
# [5 rows x 26 columns]

# %%
df = df[df['MpoEquipamentos'].isnull()==False]
df.head()
# Out:
#        Id                           documentUID  \
# 3  181508  e401f716-b9c8-44cf-a961-75dd62a2a8aa
# 4  181509  e401f716-b9c8-44cf-a961-75dd62a2a8aa
# 5  181510  e401f716-b9c8-44cf-a961-75dd62a2a8aa
# 6  181511  e401f716-b9c8-44cf-a961-75dd62a2a8aa
# 7  181512  e401f716-b9c8-44cf-a961-75dd62a2a8aa
#
#                              contentUID  \
# 3  2d387a90-353d-4411-b263-d528fbba8e7c
# 4  0ba555c0-1b6a-4d16-8f76-8758b214042c
# 5  63deb90e-ec9d-4ec1-b93c-745b0554fec8
# 6  9f861169-0b28-4673-8ffe-5f0ef3a30281
# 7  4f612ba0-e957-415c-bb37-29be4c1a5896
#
#                                           Title Level  \
# 3                  LT 230 KV Tucuruí / Altamira   3.1
# 4                    LT 230 KV Altamira / Xingu   3.2
# 5  LT 230 KV Altamira / Transamazônica C1 ou C2   3.3
# 6          LT 230 KV Transamazônica / Rurópolis   3.4
# 7         LT 230 KV Tapajós II / Transamazônica   3.5
#
#                                           hierarquia  relatedEmbedded  \
# 3  3 - PREPARAÇÃO PARA MANOBRAS DE LINHAS DE TRAN...              NaN
# 4  3 - PREPARAÇÃO PARA MANOBRAS DE LINHAS DE TRAN...              NaN
# 5  3 - PREPARAÇÃO PARA MANOBRAS DE LINHAS DE TRAN...              NaN
# 6  3 - PREPARAÇÃO PARA MANOBRAS DE LINHAS DE TRAN...              NaN
# 7  3 - PREPARAÇÃO PARA MANOBRAS DE LINHAS DE TRAN...              NaN
#
#    relatedLinks MpoAreaEletrica MpoCentro  ... MpoRevisaoReadOnly  \
# 3           NaN             2TR  COSR-NCO  ...                 27
# 4           NaN             2TR  COSR-NCO  ...                 27
# 5           NaN             2TR  COSR-NCO  ...                 27
# 6           NaN             2TR  COSR-NCO  ...                 27
# 7           NaN             2TR  COSR-NCO  ...                 27
#
#                                         MpoSubmodulo  \
# 3  5.12 - Preparação para Manobras na Área 230 kV...
# 4  5.12 - Preparação para Manobras na Área 230 kV...
# 5  5.12 - Preparação para Manobras na Área 230 kV...
# 6  5.12 - Preparação para Manobras na Área 230 kV...
# 7  5.12 - Preparação para Manobras na Área 230 kV...
#
#                                              MpoTema MpoTextoVigenciaPorData  \
# 3  Instruções da Região Norte - Área 230 kV Tramo...     2020-03-11 03:00:00
# 4  Instruções da Região Norte - Área 230 kV Tramo...     2020-03-11 03:00:00
# 5  Instruções da Região Norte - Área 230 kV Tramo...     2020-03-11 03:00:00
# 6  Instruções da Região Norte - Área 230 kV Tramo...     2020-03-11 03:00:00
# 7  Instruções da Região Norte - Área 230 kV Tramo...     2020-03-11 03:00:00
#
#            MpoTipoDocumento  \
# 3  Preparação para Manobras
# 4  Preparação para Manobras
# 5  Preparação para Manobras
# 6  Preparação para Manobras
# 7  Preparação para Manobras
#
#                                        nomeDocumento  statusItem  \
# 3  Preparação para Manobras na Área 230 kV Tramo ...    Aprovado
# 4  Preparação para Manobras na Área 230 kV Tramo ...    Aprovado
# 5  Preparação para Manobras na Área 230 kV Tramo ...    Aprovado
# 6  Preparação para Manobras na Área 230 kV Tramo ...    Aprovado
# 7  Preparação para Manobras na Área 230 kV Tramo ...    Aprovado
#
#   StatusDocumento                                              texto  \
# 3         Vigente  3.1.1.       Desenergização da LT 230 kV Tucur...
# 4         Vigente  3.2.1.       Desenergização da LT 230 kV Altam...
# 5         Vigente  3.3.1.       Desenergização da LT 230 kV Altam...
# 6         Vigente  3.4.1.       Desenergização da LT 230 kV Trans...
# 7         Vigente  3.5.1.       Desenergização da LT 230 kV Tapaj...
#
#                Created
# 3  30/07/2021 14:43:18
# 4  30/07/2021 14:43:18
# 5  30/07/2021 14:43:19
# 6  30/07/2021 14:43:19
# 7  30/07/2021 14:43:19
#
# [5 rows x 26 columns]

# %%
df['MpoCentro'].value_counts()
# Out:
# COSR-S      749
# COSR-SE     593
# COSR-NE     571
# COSR-NCO    402
# CNOS         55
# Name: MpoCentro, dtype: int64

# %%
df_list = preproc.separate_df_by_region_with_centerinfo(df, column='MpoCentro')

# %%
for sublist in range(len(df_list)):
    print(df_list[sublist][0], '- amostras :', len(df_list[sublist][1]))
# Out:
# COSR-S - amostras : 749
# CNOS - amostras : 55
# COSR-NCO - amostras : 402
# COSR-SE - amostras : 593
# COSR-NE - amostras : 571

# %%
bucket = 'ons-dl-dev-landing'
file_prefix = 'ons/mpo_ds_nlp/regioes-newjob/'

for sublist in range(len(df_list)):
    
    file_samples = file_prefix + df_list[sublist][0].lower() + '/samples.csv'
    #file_index = file_prefix + df_list[sublist][0].lower() + '/index.csv'
    
    obj_uri_samples = 's3://{}/{}'.format(bucket, file_samples)
    #obj_uri_index = 's3://{}/{}'.format(bucket, file_index)
    
    df_list[sublist][1]['texto'].to_csv(obj_uri_samples, index=False, header=False)
    #df_list[sublist][1]['Id'].to_csv(obj_uri_index, index=False, header=False)
    print(df_list[sublist][0], ' -> ', obj_uri_samples)
# Out:
# COSR-S  ->  s3://ons-dl-dev-landing/ons/mpo_ds_nlp/regioes-newjob/cosr-s/samples.csv
# CNOS  ->  s3://ons-dl-dev-landing/ons/mpo_ds_nlp/regioes-newjob/cnos/samples.csv
# COSR-NCO  ->  s3://ons-dl-dev-landing/ons/mpo_ds_nlp/regioes-newjob/cosr-nco/samples.csv
# COSR-SE  ->  s3://ons-dl-dev-landing/ons/mpo_ds_nlp/regioes-newjob/cosr-se/samples.csv
# COSR-NE  ->  s3://ons-dl-dev-landing/ons/mpo_ds_nlp/regioes-newjob/cosr-ne/samples.csv

# %% [markdown]
# Example of sample identified in NE region:

# %%
df_list[0][1]['texto'].iloc[5]
# Out:
# '3.13.2.1.                     Energização da LT 230 kV Dourados / Ivinhema 2 a partir da SE Ivinhema 2 (Sentido Normal)PassoCoordenaçãoControleComando / ExecuçãoProcedimentoItem de Controle / ObjetivoA energização desta linha de transmissão com autonomia pelo operador da instalação somente é realizada em caso de desligamento automático e se as condições especificadas na IO-OI.CO.IVI2 estiverem atendidas. Nas demais situações a energização será coordenada pelo COSR-S, conforme procedimentos a seguir:1COSR-SCOSR-SPPTEEnergizar a LT 230 kV Dourados / Ivinhema 2, pela SE Ivinhema 2.Opção 1: (de autonomia do operador)Tensão na SE Ivinhema 2igual ou inferior a 237 kVReatorreator RTDOIV 1 230 kV da SE Ivinhema 2 conectado a ser energizado juntamente com a linha de transmissão.Barramento Energizadopelo menos pela LT 230 kV Ivinhema 2 / Nova Porto Primavera C1 Opção 1a: (também de autonomia do operador)Tensão na SE Ivinhema 2igual ou inferior a 237 kVReatorreator RTDOIV 1 230 kV da SE Ivinhema 2 conectado a ser energizado juntamente com a linha de transmissão.Carga Ativana LT 230 kV Ivinhema 2 / Nova Porto Primavera C1   Opção 2:Tensão na SE Ivinhema 2igual ou inferior a 237 kVReatorreator RTDOIV 1 230 kV da SE Ivinhema 2 conectado a ser energizado juntamente com a linha de transmissão.Barramento Energizadopelo menos por um dos circuitos da LT 230 kV Ivinhema 2 / Nova Porto Primavera Opção 3:Tensão na SE Ivinhema 2igual ou inferior a 237 kVReatorreator RTDOIV 1 230 kV da SE Ivinhema 2 conectado a ser energizado juntamente com a linha de transmissão.Carga Ativaem pelo menos um dos circuitos da LT 230 kV Ivinhema 2 / Nova Porto Primavera  O fechamento do disjuntor desta linha de transmissão, com autonomia pelo operador da instalação, somente é realizado se as condições especificadas na IO-OI.CO.DOU estiverem atendidas. Nas demais situações, o fechamento do disjuntor será coordenado pelo COSR-S, conforme procedimentos a seguir:2COSR-SCOSR-SPPTEFechar, em anel, a LT 230 kV Dourados / Ivinhema 2, na SE Dourados.Ângulo igual ou inferior 26 graus: (de autonomia do operador)     em operação a UTE Caarapó. Qualquer ângulo:     fora de operação a UTE Caarapó. Se for utilizada a Opção 1 (ou 1A) na energização (de autonomia do operador), a tensão na SE Dourados, para fechamento em anel, deve ser inferior ou igual a 237 kV.2.1Caso não seja possível realizar o fechamento em anel devido à restrição angular, proceder conforme segue:2.1.1Estando em operação a UTE Caarapó, o COSR-S deve, se necessário, solicitar à Bioenergia Caarapó a desconexão do SIN da usina.     Obs.: A UTE Caarapó leva em torno de 30 min para a desconexão após a solicitação do COSR-S. Obs.: A comunicação entre o COSR-S e a UTE Caarapó é realizada pelo COI-G (Centro de Operações Integradas – Geração).   2.2Caso seja necessário reduzir o ângulo para fechamento em anel, proceder conforme segue:2.2.1COSR-SCOSR-S / COSR-SEENGIE / COPEL GeT / CESP / CGT ELETROSUL   Reduzir geração das:- UHEs Porto Primavera, Taquaruçu e Capivara;       Elevar geração das:- UHEs Gov. José Richa e Salto Osório.       Reduzir o Recebimento pela Região Sul. 3'
